# %% [markdown]
# <a href="https://colab.research.google.com/github/dahyunnnnn/IOT/blob/main/004.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Case 1. 기상청 XML 데이터 가져오기

# %%
import requests
r = requests.get('https://www.kma.go.kr/w/pop/rss-guide.do?sido=1100000000&gugun=1141000000&dong=1141058500')
print(r.text)

# URL 이용해서 XML 형식의 데이터 가져오기
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# 	<head>
# 		<title>RSS 서비스 안내</title>
# 		<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 		<meta charset="utf-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, user-scalable=yes">
# 		<meta name="format-detection" content="telephone=no">
# 		<link rel="shortcut icon" href="/w/logo_mark.png" />
#     	<link rel="apple-touch-icon-precomposed" href="/w/logo_mark.png" />
# 		<meta property="og:image" content="https://www.weather.go.kr/w/iphone-shortcut.png">
# 		<meta name="google-site-verification" content="_P1iox01__-mHQsuESbKKKQF3-fHMtks8nkf7But2KY" />
#
# 		<link href="/w/resources/css-2021/slick.css?ver=null" rel="stylesheet" type="text/css">
# 		<link href="/w/resources/css-2021/basic.css?ver=null" rel="stylesheet" type="text/css">
# 		<link href="/w/resources/css-2021/common-ui.css?ver=null" rel="stylesheet" type="text/css">
# ...
